# %%
import time
import openai
import os

from dotenv import load_dotenv

load_dotenv()

openai.api_key  = os.getenv('OPENAI_API_KEY')

import logging

logging.basicConfig(filename='logs.log', level=logging.INFO)

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

# %%
# %%script echo skipping
# text = f"""
# growl\
# growler\
# grow light\
# grown\
# grownup\
# grown-up\
# growth\
# growth factor\
# growth hormone\
# growth ring\
# Grozny\
# grub\
# grubby\
# grubstake\
# Grub Street\
# grudge\
# grudging\
# gruel\
# grueling\
# gruesome\
# gruff\
# grumble\
# grummet\
# grump\
# grumpy\
# Grünewald Matthias\
# grunge\
# grungy\
# grunion\
# grunt\
# Grus\
# Gruyère\
# gr. wt.\
# gryphon\
# GS\
# GSA\
# GSC\
# GSM\
# GSO\
# GSR\
# G spot\
# GST\
# G-string\
# G-suit\
# Gt. Brit.\
# gt.\
# GTC\
# GTG\
# gtd.\
# GTP\
# GTS\
# gtt.\
# GU\
# guac\
# guacamole\
# guacharo\
# Guadalajara\
# Guadalcanal\
# Guadalquivir\
# Guadalupe Hidalgo\
# Guadalupe Mountains\
# Guadalupe River\
# Guadeloupe\
# Guadiana\
# guaiacol\
# guaiacum\
# guaifenesin\
# guajillo\
# Guam\
# guan\
# guanabana\
# Guanabara Bay\
# guanaco\
# Guangdong\
# Guangxi\
# Guangzhou\
# guanidine\
# guanine\
# guano\
# guanosine\
# guanosine monophosphate\
# guanosine triphosphate\
# Guantánamo\
# guanylic acid\
# guar\
# guarana\
# guarani\
# Guaraní\
# guarantee\
# guarantor\
# guaranty\
# guard\
# guardant\
# guard cell\
# guarded\
# guard hair\
# guardhouse\
# guardian\
# """
# prompt = f"""
# Please suggest words of English that do not appear in the text delimited by triple backticks. The words should come after 'growl'\
# and before 'guardian' alphabetically.
#
# Some examples of English words between 'growl' and 'guardian' that are not in the list: groyne, grubble, guardee.
#
# Please return the list of suggested words in alphabetical order.
#
# ```{text}```
# """
# response = get_completion(prompt)
# logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
# print(response)

# %%
# %%script echo skipping
# text = f"""
# alter\
# """
# prompt = f"""
# Please suggest forms of the word delimited by triple backticks.
#
# For example, for the word 'amaze', forms include 'amazes' (present tense verb), 'amazed'\
# (past tense and past participle), 'unamazed' (adjective), 'amazing' (present participle), 'amazingly' (adverb), 'amazement' (noun).
#
# Please return the list of suggested words and their part of speech in alphabetical order.\
# Please suggest at least seven forms.
#
# ```{text}```
# """
# response = get_completion(prompt)
# logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
# print(response)

# %%
# %%script echo skipping
# text = f"""
# cut\
# """
# prompt = f"""
# Please suggest common English phrases that contain the word delimited by triple backticks.
#
# For example, for the word 'dark', phrases include 'dark horse', 'dark matter', 'dark money', \
# 'shot in the dark', 'after dark'
#
# Please return the list of suggested phrases in alphabetical order.\
# Please suggest as many phrases as possible, but at least ten.
#
# ```{text}```
# """
# response = get_completion(prompt)
# logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
# print(response)

# %%
# %%script echo skipping
# text = f"""
# nonabelion\
# """
# prompt = f"""
# Please create a dictionary definition for the word delimited by triple backticks.
#
# Please include a part of speech.
#
# ```{text}```
# """
# response = get_completion(prompt)
# logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
# print(response)

# %%
# %%script echo skipping
# text = f"""
# sanatively: In a sanative manner.\
# """
# prompt = f"""
# Please create an example sentence for the word and definition delimited by triple backticks.
#
# For example, for the word 'dictate' with the definition 'To order, command, control' a good example sentence would be \
# 'They wanted to dictate all the details of the contract.'
#
# ```{text}```
# """
# response = get_completion(prompt)
# logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
# print(response)

# %%
# %%script echo skipping
# text = f"""
#
# cheapfake: But today I read that fake videos are getting easier for amateurs to create and \
# share — they’re so easily produced now there’s even a new name for them: “cheapfakes,”\
# a word coined by Britt Paris, an assistant professor of library and information science at Rutgers.
#
# cheapfake: For some, the photograph, more a cheapfake than a deepfake, was the perfect encapsulation of the tech\
# industry, where issues around diversity are just an image problem that can be solved with a quick fix.
# """
# prompt = f"""
# Given the word-citation pairs delimited by triple backticks, please create a dictionary definition \
# for the word, including a part of speech.
#
# For example, for the word-citation pairs:
#
# kilonova: Neutron stars often form in pairs, then spin around each other until eventually smashing\
# together in a cataclysmic explosion called a kilonova.
#
# kilonova: Researchers on Wednesday described for the first time the contours of the type of explosion, \
# called a kilonova, that occurs when neutron stars merge.
#
# a definition would be "kilonova (noun)  A type of supernova that is underluminous, caused by the merger of two neutron stars."
#
# ```{text}```
# """
# response = get_completion(prompt)
# logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
# print(response)

# %%
text = f"""

cudeghi: The cudighi (pronounced COULD-iggy) has since become a signature food for Marquette \
County residents, a symbol of the resilience of Italian immigrant heritage in the region.

cudeghi: The word cudeghi comes from the Bergamasque dialect and was probably the \
local adaptation of the more standard coteghino, a type of sausage.
"""
prompt = f"""
Given the word-citation pairs delimited by triple backticks, please create a dictionary definition \
for the word, including a part of speech.

For example, for the word-citation pairs: 

kilonova: Neutron stars often form in pairs, then spin around each other until eventually smashing\
together in a cataclysmic explosion called a kilonova.

kilonova: Researchers on Wednesday described for the first time the contours of the type of explosion, \
called a kilonova, that occurs when neutron stars merge.

a definition would be "kilonova (noun)  A type of supernova that is underluminous, caused by the merger of two neutron stars."

```{text}```
"""
response = get_completion(prompt)
logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
print(response)

# %%
# %%script echo skipping
# text = f"""
#
# lash tab: Called a lash tab or a pig snout, these diamonds (or tilted squares?!) \
# are basically attachment points for carrying stuff outside your pack.
#
# lash tab: They're called lashtabs (or 'pig snouts' because look at em) \
# and you're meant to thread string through to tie stuff to your pack.
# """
# prompt = f"""
# Given the word-citation pairs delimited by triple backticks, please create a dictionary definition \
# for the word, including a part of speech.
#
# For example, for the word-citation pairs:
#
# kilonova: Neutron stars often form in pairs, then spin around each other until eventually smashing\
# together in a cataclysmic explosion called a kilonova.
#
# kilonova: Researchers on Wednesday described for the first time the contours of the type of explosion, \
# called a kilonova, that occurs when neutron stars merge.
#
# a definition would be "kilonova (noun)  A type of supernova that is underluminous, caused by the merger of two neutron stars."
#
# ```{text}```
# """
# response = get_completion(prompt)
# logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
# print(response)

# %%
# %%script echo skipping
# text = f"""
#
# psychobiome: Evidence is mounting for a link between the gut and the brain in what is termed the \
# psychobiome—part of the microbiome—that does just that.
#
# psychobiome: Dr John Cryan first used the term “psychobiome” to describe microbe-based treatments for\
# mental conditions, such as Holobiome’s queuine.
#
#
# """
# prompt = f"""
# Given the word-citation pairs delimited by triple backticks, please create a dictionary definition \
# for the word, including a part of speech.
#
# For example, for the word-citation pairs:
#
# kilonova: Neutron stars often form in pairs, then spin around each other until eventually smashing\
# together in a cataclysmic explosion called a kilonova.
#
# kilonova: Researchers on Wednesday described for the first time the contours of the type of explosion, \
# called a kilonova, that occurs when neutron stars merge.
#
# a definition would be "kilonova (noun)  A type of supernova that is underluminous, caused by the merger of two neutron stars."
#
# ```{text}```
# """
# response = get_completion(prompt)
# logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
# print(response)

# %%
# %%script echo skipping
# text = f"""
#
# booksona: Get book recommendations you’ll want to bump to the top of your TBR. Just answer a few quick Q’s and\
# we’ll  reveal who you are as a reader, plus custom picks just for your #Booksona.
#
# booksona: What's a booksona? It's you, but as a book. It's a vibe thing.
# """
# prompt = f"""
# Given the word-citation pairs delimited by triple backticks, please create a dictionary definition \
# for the word, including a part of speech.
#
# For example, for the word-citation pairs:
#
# kilonova: Neutron stars often form in pairs, then spin around each other until eventually smashing\
# together in a cataclysmic explosion called a kilonova.
#
# kilonova: Researchers on Wednesday described for the first time the contours of the type of explosion, \
# called a kilonova, that occurs when neutron stars merge.
#
# a definition would be "kilonova (noun)  A type of supernova that is underluminous, caused by the merger of two neutron stars."
#
# ```{text}```
# """
# response = get_completion(prompt)
# logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
# print(response)

# %%
# %%script echo skipping
# text = f"""
#
# claxonomy: So, in the interest of systematic knowledge (and public safety), this essay tabulates \
# the streets’ honks into a taxonomy of cláxones [horns], a “claxonomy” of Mexico City’s traffic.
#
# """
# prompt = f"""
# Given the word-citation pairs delimited by triple backticks, please create a dictionary definition \
# for the word, including a part of speech.
#
# For example, for the word-citation pairs:
#
# kilonova: Neutron stars often form in pairs, then spin around each other until eventually smashing\
# together in a cataclysmic explosion called a kilonova.
#
# kilonova: Researchers on Wednesday described for the first time the contours of the type of explosion, \
# called a kilonova, that occurs when neutron stars merge.
#
# a definition would be "kilonova (noun)  A type of supernova that is underluminous, caused by the merger of two neutron stars."
#
# ```{text}```
# """
# response = get_completion(prompt)
# logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
# print(response)

# %%
text = f"""

whimsigoth: Throw it all into the proverbial blender and you end up with whimsigoth’s slip dresses, chunky footwear,\
maxi skirts, celestial jewelry, corsets, and paisley tops.

whimsigoth: The dominant color palette of whimsigoth fans is a kaleidoscope of purples, blues, dark reds, greens,\
brown, oftentimes with a pop of orange or yellow. 
"""
prompt = f"""
Given the word-citation pairs delimited by triple backticks, please create a dictionary definition \
for the word, including a part of speech.

For example, for the word-citation pairs: 

kilonova: Neutron stars often form in pairs, then spin around each other until eventually smashing\
together in a cataclysmic explosion called a kilonova.

kilonova: Researchers on Wednesday described for the first time the contours of the type of explosion, \
called a kilonova, that occurs when neutron stars merge.

a definition would be "kilonova (noun)  A type of supernova that is underluminous, caused by the merger of two neutron stars."

```{text}```
"""
response = get_completion(prompt)
logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
print(response)

# %%
# %%script echo skipping
# text = f"""
#
# Calexican: Located in an old filling station in gourmand-centric Kings Cross, \
# Shrimpy's serves what they call Calexican (Cali-Mexican) fare.
#
# Calexican: Birria tacos are a legendary Calexican food truck staple in LA and an \
# Instagram favourite - for good reason.
# """
# prompt = f"""
# Given the word-citation pairs delimited by triple backticks, please create a dictionary definition \
# for the word, including a part of speech.
#
# For example, for the word-citation pairs:
#
# kilonova: Neutron stars often form in pairs, then spin around each other until eventually smashing\
# together in a cataclysmic explosion called a kilonova.
#
# kilonova: Researchers on Wednesday described for the first time the contours of the type of explosion, \
# called a kilonova, that occurs when neutron stars merge.
#
# a definition would be "kilonova (noun)  A type of supernova that is underluminous, caused by the merger of two neutron stars."
#
# ```{text}```
# """
# response = get_completion(prompt)
# logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
# print(response)

# %%
# %%script echo skipping
# text = f"""
#
# hipsterical: The store is decorated with white tiles, hipsterical and fashionable at the same time.
#
# hipsterical: Written in the sort of hipsterical slanguage that can only be understood by the underprivileged\
# few who really dig that crazy talk”
# """
# prompt = f"""
# Given the word-citation pairs delimited by triple backticks, please create a dictionary definition \
# for the word, including a part of speech.
#
# For example, for the word-citation pairs:
#
# kilonova: Neutron stars often form in pairs, then spin around each other until eventually smashing\
# together in a cataclysmic explosion called a kilonova.
#
# kilonova: Researchers on Wednesday described for the first time the contours of the type of explosion, \
# called a kilonova, that occurs when neutron stars merge.
#
# a definition would be "kilonova (noun)  A type of supernova that is underluminous, caused by the merger of two neutron stars."
#
# ```{text}```
# """
# response = get_completion(prompt)
# logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
# print(response)

# %%
# %%script echo skipping
# text = f"""
#
# boujetto: “Ava is that boujetto hood chick from around the way,” Frazier says “She’s been around a couple blocks, \
# but she’s a teacher now. And this season we wanted to embrace that hood-classy vibe for her.”
#
# """
# prompt = f"""
# Given the word-citation pairs delimited by triple backticks, please create a dictionary definition \
# for the word, including a part of speech.
#
# For example, for the word-citation pairs:
#
# kilonova: Neutron stars often form in pairs, then spin around each other until eventually smashing\
# together in a cataclysmic explosion called a kilonova.
#
# kilonova: Researchers on Wednesday described for the first time the contours of the type of explosion, \
# called a kilonova, that occurs when neutron stars merge.
#
# a definition would be "kilonova (noun)  A type of supernova that is underluminous, caused by the merger of two neutron stars."
#
# ```{text}```
# """
# response = get_completion(prompt)
# logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
# print(response)

# %%
# %%script echo skipping
# text = f"""
#
# triggering: We don’t want the statue moved because we’re prim and proper prudes, but because /
# we’d rather avoid looking at a creepy, potentially triggering sculpture on our /
# way to class.
#
# triggering: Remove triggering material when it does not contribute directly /
# to the course learning goals.
#
# """
# prompt = f"""
# Given the word-citation pairs delimited by triple backticks, please create a dictionary definition \
# for the word, including a part of speech.
#
# For example, for the word-citation pairs:
#
# kilonova: Neutron stars often form in pairs, then spin around each other until eventually smashing\
# together in a cataclysmic explosion called a kilonova.
#
# kilonova: Researchers on Wednesday described for the first time the contours of the type of explosion, \
# called a kilonova, that occurs when neutron stars merge.
#
# a definition would be "kilonova (noun)  A type of supernova that is underluminous, caused by the merger of two neutron stars."
#
# ```{text}```
# """
# response = get_completion(prompt)
# logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
# print(response)

# %%
text = f"""

styptic: Tending to check bleeding by contracting the tissues or blood vessels; hemostatic.


"""
prompt = f"""
Given the word-definition pair delimited by triple backticks, please rewrite the definition to be suitable for children \
ages 7-10.

For example, for the word-definition pair:  

xenophobia: A strong antipathy or aversion to strangers or foreigners.

a good rewritten definition would be "Fear of strangers or of foreign cultures."

```{text}```
"""
response = get_completion(prompt)
logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
print(response)

# %%
text = f"""

styptic: Tending to check bleeding by contracting the tissues or blood vessels; hemostatic.


"""
prompt = f"""
Given the word-definition pair delimited by triple backticks, please rewrite the definition to be suitable for children \
ages 7-10.

For example, for the word-definition pair:  

xenophobia: A strong antipathy or aversion to strangers or foreigners.

a good rewritten definition would be "Xenophobia is the fear of strangers or of foreign cultures."

```{text}```
"""
response = get_completion(prompt)
logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
print(response)

# %%
text = f"""

careen: To lurch or sway violently from side to side.


"""
prompt = f"""
Given the word-definition pair delimited by triple backticks, please rewrite the definition to be suitable for children \
ages 7-10.

For example, for the word-definition pair:  

xenophobia: A strong antipathy or aversion to strangers or foreigners.

a good rewritten definition would be "Xenophobia is the fear of strangers or of foreign cultures."

```{text}```
"""
response = get_completion(prompt)
logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
print(response)

# %%
text = f"""

screwball: An eccentric, impulsively whimsical, or irrational person.


"""
prompt = f"""
Given the word-definition pair delimited by triple backticks, please rewrite the definition to be suitable for children \
ages 7-10.

For example, for the word-definition pair:  

xenophobia: A strong antipathy or aversion to strangers or foreigners.

a good rewritten definition would be "Xenophobia is the fear of strangers or of foreign cultures."

```{text}```
"""
response = get_completion(prompt)
logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
print(response)

# %%
text = f"""

biogeophysical: Of or pertaining to the composite of biological, geological, and physical processes operating \
in an area
"""
prompt = f"""
Given the word-definition pair delimited by triple backticks, please rewrite the definition to be suitable for children \
ages 7-10.

For example, for the word-definition pair:  

xenophobia: A strong antipathy or aversion to strangers or foreigners.

a good rewritten definition would be "Xenophobia is the fear of strangers or of foreign cultures."

```{text}```
"""
response = get_completion(prompt)
logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
print(response)

# %%
text = f"""

consolatory: Tending to give consolation; assuaging grief or other mental distress; comforting; cheering; encouraging.


"""
prompt = f"""
Given the word-definition pair delimited by triple backticks, please rewrite the definition to be suitable for children \
ages 7-10.

For example, for the word-definition pair:  

xenophobia: A strong antipathy or aversion to strangers or foreigners.

a good rewritten definition would be "Xenophobia is the fear of strangers or of foreign cultures."

```{text}```
"""
response = get_completion(prompt)
logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
print(response)

# %%
text = f"""

disgorge: To surrender (stolen goods or money, for example) unwillingly.


"""
prompt = f"""
Given the word-definition pair delimited by triple backticks, please rewrite the definition to be suitable for children \
ages 7-10.

For example, for the word-definition pair:  

xenophobia: A strong antipathy or aversion to strangers or foreigners.

a good rewritten definition would be "Xenophobia is the fear of strangers or of foreign cultures."

```{text}```
"""
response = get_completion(prompt)
logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
print(response)

# %%
text = f"""

drone (third-person singular simple present drones, present participle droning, simple past and past participle droned)

    To produce a low-pitched hum or buzz.
    To speak in a monotone way.


"""
prompt = f"""
Given dictionary entry delimited by triple backticks, please give senses not included in the entry \
but that have the same part of speech.

For example, for the entry  

demise (third-person singular simple present demises, present participle demising, simple past and past participle demised)

    (transitive, obsolete, law) To give.
    (transitive, law) To convey, as by will or lease.
    (transitive, law) To transmit by inheritance.
    (intransitive, law) To pass by inheritance.
    (intransitive) To die.

a good additional sense would be "(transitive) To be fired from a job."

```{text}```
"""
response = get_completion(prompt)
logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
print(response)

# %%
text = f"""
sanatively: In a sanative manner.\
"""
prompt = f"""
Please create an example sentence for the word and definition delimited by triple backticks. 
The example sentence should be less than 50 characters.

For example, for the word 'dictate' with the definition 'To order, command, control' a good example sentence would be \
'They wanted to dictate the contract's terms.'

```{text}```
"""
response = get_completion(prompt)
logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
print(response)

# %%
text = f"""
yelp: To utter a short, sharp bark or cry.\
"""
prompt = f"""
Please create an example sentence for the word and definition delimited by triple backticks. 
The example sentence should be less than 50 characters.

For example, for the word 'dictate' with the definition 'To order, command, control' a good example sentence would be \
'They wanted to dictate the contract's terms.'

```{text}```
"""
response = get_completion(prompt)
logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
print(response)

# %%
text = f"""
palimpsest: A manuscript or document that has been erased or scraped clean, for reuse of the paper, parchment, vellum, or other medium on which it was written. \
"""
prompt = f"""
Please create an example sentence for the word and definition delimited by triple backticks. 
The example sentence should be less than 50 characters.

For example, for the word 'dictate' with the definition 'To order, command, control' a good example sentence would be \
'They wanted to dictate the contract's terms.'

```{text}```
"""
response = get_completion(prompt)
logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
print(response)

# %%
text = f"""
surrealist: of, or relating to surrealism.\
"""
prompt = f"""
Please create an example sentence for the word and definition delimited by triple backticks. 
The example sentence should be less than 50 characters.

For example, for the word 'dictate' with the definition 'To order, command, control' a good example sentence would be \
'They wanted to dictate the contract's terms.'

```{text}```
"""
response = get_completion(prompt)
logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
print(response)

# %%
text = f"""
asshat
assiduity
chauffeur
chav
chaw
cheesecake
cheesehead
chubs
chuck
colonel
colonizer
colony
"""
prompt = f"""
Please create labels for the words delimited by triple backticks.

For example, the word 'biddy' should be labeled as 'derogatory'. Please return suggestions in the format \
word, label. For example: biddy, derogatory. If a word does not need a label, just return the word.

```{text}```
"""
response = get_completion(prompt)
logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
print(response)

# %%
text = f"""
ageusia (uh-gyou-zee-uh)
"""
prompt = f"""
Please create pronunciations in International Phonetic Alphabet for the word and respelling pair \
delimited by triple backticks.

For example, an IPA transcription for the word 'diphtheria' (dif-THEER-ee-uh) is /dɪfˈθɪɹi.ə/

```{text}```
"""
response = get_completion(prompt)
logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
print(response)

# %%
text = f"""
heutagogy (hyoo-tuh-goh-jee) 
"""
prompt = f"""
Please create pronunciations in International Phonetic Alphabet for the word and respelling pair \
delimited by triple backticks.

For example, an IPA transcription for the word 'diphtheria' (dif-THEER-ee-uh) is /dɪfˈθɪɹi.ə/

```{text}```
"""
response = get_completion(prompt)
logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
print(response)

# %%
text = f"""
oomycete  (oh-oh-MY-seat)
"""
prompt = f"""
Please create pronunciations in International Phonetic Alphabet for the word and respelling pair \
delimited by triple backticks.

For example, an IPA transcription for the word 'diphtheria' (dif-THEER-ee-uh) is /dɪfˈθɪɹi.ə/

```{text}```
"""
response = get_completion(prompt)
logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
print(response)

# %%
text = f"""
comptroller (con-TROLL-er)
"""
prompt = f"""
Please create pronunciations in International Phonetic Alphabet for the word and respelling pair \
delimited by triple backticks.

For example, an IPA transcription for the word 'diphtheria' (dif-THEER-ee-uh) is /dɪfˈθɪɹi.ə/

```{text}```
"""
response = get_completion(prompt)
logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
print(response)

# %%
text = f"""
hyperbole (high-PER-boh-lee)
"""
prompt = f"""
Please create pronunciations in International Phonetic Alphabet for the word and respelling pair \
delimited by triple backticks.

For example, an IPA transcription for the word 'diphtheria' (dif-THEER-ee-uh) is /dɪfˈθɪɹi.ə/

```{text}```
"""
response = get_completion(prompt)
logging.info({"time": time.strftime('%Y-%m-%dT%H:%M:%S%z'), "prompt": prompt, "response": response})
print(response)
